# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 2 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here
print("Jasmine Liu")
# Out:
# Jasmine Liu

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:
"I will abide by Emory's code of conduct"

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pyplot", and "pandas"

# %%
# Write your answer here
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <font size = "5">
#
# Import the dataset "data_quiz/fifa23_players_basic.csv"
#
# - It's a dataset on professional soccer players
# - Rows correspond to players (18,539)
# - Columns contain attributes of players (32)
# - Try to view the dataset before starting

# %%
# Write your own code
data_quiz = pd.read_csv("data_quiz/fifa23_players_basic.csv")

# %% [markdown]
# <font size = "5">
#
# (a) Create a function and apply it to a column <br>
#
# <font size = "3">
#
# Step 1:
# - Define a function with a parameter "country"
# - If "country == United States", status = "US national"
# - Otherwise, status = "Not a US national"
# - The function returns "status"
#
# Step 2:
# - Extract the column "Nationality" in the dataset <br>
# (be carefeful to write the "N" (capitalized)
# - Create a new variable called "is_us_national" <br>
# to assign each player to the correct age bracket
#
# HINT: Use the ".apply()" function

# %%
# Write your own code
def fn_country(country):
    if country == "United States":
        status = "US national"
    else:
        status = "Not a US national"
    return(status)
data_quiz["is_us_national"] = data_quiz["Nationality"].apply(fn_country)
display(data_quiz)
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
#       Positions Played Best Position          Nationality  \
# 0                   RW           CAM            Argentina
# 1                CF,ST            CF               France
# 2                   ST            ST               Poland
# 3               CM,CAM            CM              Belgium
# 4                ST,LW            ST               France
# ...                ...           ...                  ...
# 18534            ST,RM           CAM  Republic of Ireland
# 18535              CDM           CDM             China PR
# 18536               CM            RM     Northern Ireland
# 18537               CB            CB  Republic of Ireland
# 18538               LB            LB                India
#
#                                              Image Link  Age  ...  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...
# 3      https://cdn.sofifa.net/players/192/985/23_60.png   31  ...
# 4      https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# ...                                                 ...  ...  ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png   21  ...
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png   17  ...
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png   18  ...
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png   17  ...
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png   25  ...
#
#                   National Team Image Link  National Team Position  \
# 0      https://cdn.sofifa.net/flags/ar.png                      RW
# 1      https://cdn.sofifa.net/flags/fr.png                      ST
# 2      https://cdn.sofifa.net/flags/pl.png                      ST
# 3      https://cdn.sofifa.net/flags/be.png                      RF
# 4      https://cdn.sofifa.net/flags/fr.png                      ST
# ...                                    ...                     ...
# 18534                                    -                       -
# 18535                                    -                       -
# 18536                                    -                       -
# 18537                                    -                       -
# 18538                                    -                       -
#
#        National Team Jersey Number  Attacking Work Rate Defensive Work Rate  \
# 0                               10                  Low                 Low
# 1                               19               Medium              Medium
# 2                                9                 High              Medium
# 3                                7                 High                High
# 4                               10                 High                 Low
# ...                            ...                  ...                 ...
# 18534                            -               Medium              Medium
# 18535                            -               Medium              Medium
# 18536                            -                 High              Medium
# 18537                            -               Medium              Medium
# 18538                            -               Medium              Medium
#
#           is_us_national           a status     b           c
# 0      Not a US national  3755973796      0  1296  3747153796
# 1      Not a US national  3344887225      0  1225  3336795225
# 2      Not a US national  2968506256      1  1156  2961101056
# 3      Not a US national  2311878724      1  1024  2305728324
# 4      Not a US national   701084484      1   784   698122084
# ...                  ...         ...    ...   ...         ...
# 18534  Not a US national   485629369      0   169   486775969
# 18535  Not a US national   208340356      0   256   209265156
# 18536  Not a US national   262278025      1    25   262602025
# 18537  Not a US national   208455844      0   144   209149444
# 18538  Not a US national   975625225      1   225   977500225
#
# [18539 rows x 37 columns]

# %% [markdown]
# <font size = "5">
#
# (b) Use queries + global variables
#
# <font size = "3">
#
# - Compute the median of the column "Value(in Euro)" <br>
# and store it as a variable
# - Subset the players whose value is above the mean value <br>
#   using ".query()"
#
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 10) <br>
# Reference the column as ``` `Wage(in Euro)`    ``` inside .query()

# %%
# Write your own code
median_euro = data_quiz["Wage(in Euro)"].median()
players_above_median = data_quiz.query("`Wage(in Euro)` >= @median_euro")

# %% [markdown]
# <font size = "5">
#
# (c) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# - Use ".sort_values()" to order the "Potental" column <br>
# from highest to lowest
# - Get a subset with the 15 players with the highest potential

# %%
# Write your own code
sorted_data = data_quiz.sort_values(by="Potential", ascending = False)
top_potential = sorted_data.iloc[0:15,:]
display(top_potential)
# Out:
#           Known As                         Full Name  Overall  Potential  \
# 4        K. Mbappé                     Kylian Mbappé       91         95
# 21      E. Haaland                    Erling Haaland       88         94
# 82           Pedri              Pedro González López       85         93
# 83        P. Foden                        Phil Foden       85         92
# 63    Vinícius Jr.  Vinícius José de Oliveira Júnior       86         92
# 42      F. de Jong                   Frenkie de Jong       87         92
# 22   G. Donnarumma              Gianluigi Donnarumma       88         92
# 0         L. Messi                      Lionel Messi       91         91
# 16         Ederson         Ederson Santana de Moraes       89         91
# 1       K. Benzema                     Karim Benzema       91         91
# 152    D. Vlahović                    Dušan Vlahović       84         91
# 138     K. Havertz                       Kai Havertz       84         91
# 127       J. Tartt                       Jamie Tartt       84         91
# 124  J. Bellingham                   Jude Bellingham       84         91
# 20      Rúben Dias      Rúben Santos Gato Alves Dias       88         91
#
#      Value(in Euro) Positions Played Best Position  Nationality  \
# 4         190500000            ST,LW            ST       France
# 21        148000000               ST            ST       Norway
# 82        116000000               CM            CM        Spain
# 83        109500000        LW,CF,CAM           CAM      England
# 63        109000000               LW            LW       Brazil
# 42        116500000               CM            CM  Netherlands
# 22        103500000               GK            GK        Italy
# 0          54000000               RW           CAM    Argentina
# 16         88000000               GK            GK       Brazil
# 1          64000000            CF,ST            CF       France
# 152        86500000               ST            ST       Serbia
# 138        84500000        CAM,CF,ST           CAM      Germany
# 127        85500000               ST           CAM      England
# 124        81500000            CM,LM            CM      England
# 20        107500000               CB            CB     Portugal
#
#                                            Image Link  Age  ...  \
# 4    https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# 21   https://cdn.sofifa.net/players/239/085/23_60.png   21  ...
# 82   https://cdn.sofifa.net/players/251/854/23_60.png   19  ...
# 83   https://cdn.sofifa.net/players/237/692/23_60.png   22  ...
# 63   https://cdn.sofifa.net/players/238/794/23_60.png   21  ...
# 42   https://cdn.sofifa.net/players/228/702/23_60.png   25  ...
# 22   https://cdn.sofifa.net/players/230/621/23_60.png   23  ...
# 0    https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 16   https://cdn.sofifa.net/players/210/257/23_60.png   28  ...
# 1    https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 152  https://cdn.sofifa.net/players/246/430/23_60.png   22  ...
# 138  https://cdn.sofifa.net/players/235/790/23_60.png   23  ...
# 127  https://cdn.sofifa.net/players/269/761/23_60.png   24  ...
# 124  https://cdn.sofifa.net/players/252/371/23_60.png   19  ...
# 20   https://cdn.sofifa.net/players/239/818/23_60.png   25  ...
#
#      International Reputation  National Team Name  \
# 4                           4              France
# 21                          4              Norway
# 82                          2               Spain
# 83                          3             England
# 63                          2                   -
# 42                          3         Netherlands
# 22                          3               Italy
# 0                           5           Argentina
# 16                          3                   -
# 1                           4              France
# 152                         2                   -
# 138                         3             Germany
# 127                         1                   -
# 124                         2             England
# 20                          3            Portugal
#
#                     National Team Image Link  National Team Position  \
# 4        https://cdn.sofifa.net/flags/fr.png                      ST
# 21       https://cdn.sofifa.net/flags/no.png                      ST
# 82       https://cdn.sofifa.net/flags/es.png                      CM
# 83   https://cdn.sofifa.net/flags/gb-eng.png                      RW
# 63       https://cdn.sofifa.net/flags/br.png                       -
# 42       https://cdn.sofifa.net/flags/nl.png                     CDM
# 22       https://cdn.sofifa.net/flags/it.png                      GK
# 0        https://cdn.sofifa.net/flags/ar.png                      RW
# 16       https://cdn.sofifa.net/flags/br.png                       -
# 1        https://cdn.sofifa.net/flags/fr.png                      ST
# 152                                        -                       -
# 138      https://cdn.sofifa.net/flags/de.png                     SUB
# 127  https://cdn.sofifa.net/flags/gb-eng.png                       -
# 124  https://cdn.sofifa.net/flags/gb-eng.png                     SUB
# 20       https://cdn.sofifa.net/flags/pt.png                      CB
#
#     National Team Jersey Number  Attacking Work Rate  Defensive Work Rate  \
# 4                            10                 High                  Low
# 21                            9                 High               Medium
# 82                           10                 High                 High
# 83                           20                 High                 High
# 63                            -                 High               Medium
# 42                           21                 High               Medium
# 22                           21               Medium               Medium
# 0                            10                  Low                  Low
# 16                            -               Medium               Medium
# 1                            19               Medium               Medium
# 152                           -               Medium               Medium
# 138                           7               Medium               Medium
# 127                           -                 High                  Low
# 124                          26                 High                 High
# 20                            4               Medium                 High
#
#     is_us_national           a status
# 4      US national   701084484      1
# 21     US national   487305625      1
# 82     US national   326597184      0
# 83     US national   586802176      0
# 63     US national   487217329      0
# 42     US national   978250729      1
# 22     US national   700925625      0
# 0      US national  3755973796      0
# 16     US national  1538914441      0
# 1      US national  3344887225      0
# 152    US national   586753729      1
# 138    US national   700872676      1
# 127    US national   830880625      0
# 124    US national   326524900      0
# 20     US national   978188176      0
#
# [15 rows x 35 columns]

# %% [markdown]
# <font size = "5">
#
# (d) Create a function with five inputs $f(y,x,b0,b1,b2)$
#
# <font size = "3">
#
# $\qquad e = y - b_0 - b_1 * x - b_2 * x^2 $ <br>
# $\qquad e2 = e^2$
#
# - The function should return the mean of e2
# - This is the mean-square error (mse)
# - Call the function "fn_mse"
# - Let $y$ be the column "Potential"
# - Let $x$ be the column "Age"
# - Does <br>
# $\qquad (b_0 = 90, b_1 = -1, b2 = -50)$ or <br>
# $\qquad (b_0 = 90, b_1 = -1, b2 = 0)$ or <br>
# $\qquad (b_0 = 90, b_1 = -1, b3 = 50)$ <br>
# produce the lowest value of mse?

# %%
# Write your own code

def fn_mse(y,x,b0,b1,b2):
    e2 = (y - b0 - b1 * x - b2 * x**2) **2
    return(e2)

y = data_quiz["Potential"]
x = data_quiz["Age"]
data_quiz["a"] = fn_mse(y,x,90,-1,-50)
data_quiz["b"] = fn_mse(y,x,90,-1,0)
data_quiz["c"] = fn_mse(y,x,90, -1, 50)
data_quiz.sort_values(by = "a", ascending = True)
data_quiz.sort_values(by = "b", ascending = True)
data_quiz.sort_values(by = "c", ascending = True)

#90,-1,0 produces the smalles value of mse
# Out:
#           Known As          Full Name  Overall  Potential  Value(in Euro)  \
# 16084     S. Ngoma        Serge Ngoma       58         82          650000
# 11481    O. Vargas        Obed Vargas       64         81         1500000
# 14439      W. Amey        Wisdom Amey       61         81          850000
# 17796     Y. Gomis         Yoni Gomis       53         79          350000
# 17813    D. Lobban       Dylan Lobban       53         79          375000
# ...            ...                ...      ...        ...             ...
# 13086   A. Narciso    Antonio Narciso       62         62           45000
# 15525  J. Szmatuła     Jakub Szmatuła       59         59           25000
# 3276    S. Torrico  Sebastián Torrico       72         72          250000
# 13548     S. Lukić       Stojan Lukić       62         62           45000
# 592      G. Buffon   Gianluigi Buffon       79         79         1900000
#
#       Positions Played Best Position             Nationality  \
# 16084               RW            RM           United States
# 11481        CM,CDM,RM           CAM           United States
# 14439               CB            CB                   Italy
# 17796               CB            CB                  France
# 17813              CAM           CAM                Scotland
# ...                ...           ...                     ...
# 13086               GK            GK                   Italy
# 15525               GK            GK                  Poland
# 3276                GK            GK               Argentina
# 13548               GK            GK  Bosnia and Herzegovina
# 592                 GK            GK                   Italy
#
#                                              Image Link  Age  ...  \
# 16084  https://cdn.sofifa.net/players/267/796/23_60.png   16  ...
# 11481  https://cdn.sofifa.net/players/263/701/23_60.png   16  ...
# 14439  https://cdn.sofifa.net/players/269/183/23_60.png   16  ...
# 17796  https://cdn.sofifa.net/players/271/250/23_60.png   16  ...
# 17813  https://cdn.sofifa.net/players/269/086/23_60.png   16  ...
# ...                                                 ...  ...  ...
# 13086  https://cdn.sofifa.net/players/178/434/23_60.png   41  ...
# 15525  https://cdn.sofifa.net/players/155/422/23_60.png   41  ...
# 3276   https://cdn.sofifa.net/players/216/692/23_60.png   42  ...
# 13548  https://cdn.sofifa.net/players/213/483/23_60.png   42  ...
# 592    https://cdn.sofifa.net/players/001/179/23_60.png   44  ...
#
#                       National Team Image Link  National Team Position  \
# 16084      https://cdn.sofifa.net/flags/us.png                       -
# 11481      https://cdn.sofifa.net/flags/us.png                       -
# 14439      https://cdn.sofifa.net/flags/it.png                       -
# 17796      https://cdn.sofifa.net/flags/fr.png                       -
# 17813  https://cdn.sofifa.net/flags/gb-sct.png                       -
# ...                                        ...                     ...
# 13086      https://cdn.sofifa.net/flags/it.png                       -
# 15525      https://cdn.sofifa.net/flags/pl.png                       -
# 3276       https://cdn.sofifa.net/flags/ar.png                       -
# 13548                                        -                       -
# 592        https://cdn.sofifa.net/flags/it.png                       -
#
#        National Team Jersey Number  Attacking Work Rate Defensive Work Rate  \
# 16084                            -                 High              Medium
# 11481                            -                 High              Medium
# 14439                            -               Medium              Medium
# 17796                            -               Medium              Medium
# 17813                            -               Medium              Medium
# ...                            ...                  ...                 ...
# 13086                            -               Medium              Medium
# 15525                            -               Medium              Medium
# 3276                             -               Medium              Medium
# 13548                            -               Medium              Medium
# 592                              -               Medium              Medium
#
#        is_us_national           a status     b           c
# 16084     US national   164044864      0    64   163635264
# 11481     US national   164019249      0    49   163660849
# 14439     US national   164019249      1    49   163660849
# 17796     US national   163968025      0    25   163712025
# 17813     US national   163968025      0    25   163712025
# ...               ...         ...    ...   ...         ...
# 13086     US national  7066587969      1   169  7062217369
# 15525     US national  7066083600      1   100  7062721600
# 3276      US national  7783474176      1   576  7775006976
# 13548     US national  7781709796      1   196  7776770596
# 592       US national  9376629889      1  1089  9363852289
#
# [18539 rows x 37 columns]

# %% [markdown]
# <font size = "5">
#
# (e) Split a dataset into subsets
#
# <font size = "3">
#
# - Create ``` list_status = [0,1]```
# - Create ``` list_prob = [0.5, 0.5]```
# - Create a new variable $n$ with the number of rows of the dataset
# - Use
# ```python
#     np.random.choice(list_status,
#                      size = n,
#                      p = list_prob)
# ```
# $\qquad$ to create a new column called "status" <br>
# $\qquad$ which randomly assigns each row to "0" with probability 50% <br>
# $\qquad$ and to 1 with probability 50%
# - Use .query() to subset all observations with status == 0.<br>
# store it in a new dataset called "data0"
# - Use .query() to subset all observations with status == 1.<br>
# store it in a new dataset called "data1"

# %%
# Write your own code
list_status = [0,1]
list_prob = [0.5,0.5]
n = len(data_quiz)
data_quiz["status"] = np.random.choice(list_status, size = n, p = list_prob)

data0 = data_quiz.query("status == 0")
data1 = data_quiz.query("status == 1")

display(data0)
# Out:
#                 Known As                     Full Name  Overall  Potential  \
# 0               L. Messi                  Lionel Messi       91         91
# 1             K. Benzema                 Karim Benzema       91         91
# 7               M. Neuer                  Manuel Neuer       90         90
# 8      Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro       90         90
# 12                H. Son                 Heung Min Son       89         89
# ...                  ...                           ...      ...        ...
# 18532           H. Singh             Harmanpreet Singh       48         56
# 18533          Pi Ziyang                     Ziyang Pi       47         60
# 18534         D. Collins                Darren Collins       47         56
# 18535       Yang Dejiang                  Dejiang Yang       47         57
# 18537       D. McCallion              Daithí McCallion       47         61
#
#        Value(in Euro) Positions Played Best Position          Nationality  \
# 0            54000000               RW           CAM            Argentina
# 1            64000000            CF,ST            CF               France
# 7            13500000               GK            GK              Germany
# 8            41000000               ST            ST             Portugal
# 12          101000000            LW,LM            LW       Korea Republic
# ...               ...              ...           ...                  ...
# 18532          100000               ST            ST                India
# 18533          110000               CM           CAM             China PR
# 18534          110000            ST,RM           CAM  Republic of Ireland
# 18535           90000              CDM           CDM             China PR
# 18537          100000               CB            CB  Republic of Ireland
#
#                                              Image Link  Age  ...  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 7      https://cdn.sofifa.net/players/167/495/23_60.png   36  ...
# 8      https://cdn.sofifa.net/players/020/801/23_60.png   37  ...
# 12     https://cdn.sofifa.net/players/200/104/23_60.png   29  ...
# ...                                                 ...  ...  ...
# 18532  https://cdn.sofifa.net/players/259/745/23_60.png   20  ...
# 18533  https://cdn.sofifa.net/players/269/066/23_60.png   19  ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png   21  ...
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png   17  ...
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png   17  ...
#
#        International Reputation  National Team Name  \
# 0                             5           Argentina
# 1                             4              France
# 7                             5             Germany
# 8                             5            Portugal
# 12                            4                   -
# ...                         ...                 ...
# 18532                         1                   -
# 18533                         1                   -
# 18534                         1                   -
# 18535                         1                   -
# 18537                         1                   -
#
#                   National Team Image Link  National Team Position  \
# 0      https://cdn.sofifa.net/flags/ar.png                      RW
# 1      https://cdn.sofifa.net/flags/fr.png                      ST
# 7      https://cdn.sofifa.net/flags/de.png                      GK
# 8      https://cdn.sofifa.net/flags/pt.png                      ST
# 12                                       -                       -
# ...                                    ...                     ...
# 18532                                    -                       -
# 18533                                    -                       -
# 18534                                    -                       -
# 18535                                    -                       -
# 18537                                    -                       -
#
#       National Team Jersey Number  Attacking Work Rate  Defensive Work Rate  \
# 0                              10                  Low                  Low
# 1                              19               Medium               Medium
# 7                               1               Medium               Medium
# 8                               7                 High                  Low
# 12                              -                 High               Medium
# ...                           ...                  ...                  ...
# 18532                           -               Medium                  Low
# 18533                           -               Medium               Medium
# 18534                           -               Medium               Medium
# 18535                           -               Medium               Medium
# 18537                           -               Medium               Medium
#
#       is_us_national           a status
# 0        US national  3755973796      0
# 1        US national  3344887225      0
# 7        US national  4203706896      0
# 8        US national  4690469169      0
# 12       US national  1770558084      0
# ...              ...         ...    ...
# 18532    US national   399440196      0
# 18533    US national   325405521      0
# 18534    US national   485629369      0
# 18535    US national   208340356      0
# 18537    US national   208455844      0
#
# [9316 rows x 35 columns]

# %% [markdown]
# <font size = "5">
#
# (f) Create two overlapping histogram plots
#
# <font size = "3">
#
# - This function requires the two datasets you created in (e)
# - Display the distribution of "Overall" for "data0" and "data1"
# - Use the "alpha" option to make the graphs semitransparent
# - You will need to add a legend, label the axes, and the title
#
# Note: The goal of this question is to illustrate that random <br>
# assignment produces very similar distributions between two groups

# %%
# Write your own code
plt.hist(x= data0["Overall"], alpha=0.5)
plt.hist(x= data1["Overall"], alpha = 0.5)
plt.xlabel("Overall")
plt.ylabel("count")
plt.title("Overall Distribution for data0 and data1")
x= ["data0", "data1"]
plt.legend(labels = x,
           title = "data")
plt.show()
