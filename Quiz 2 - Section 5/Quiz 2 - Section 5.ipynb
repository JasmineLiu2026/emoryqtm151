# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 2 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here
print("Jasmine Liu")
# Out:
# Jasmine Liu

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:
"I will abide by Emory's code of conduct"

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pyplot", and "pandas"

# %%
# Write your answer here
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <font size = "5">
#
# Import the dataset "data_quiz/fifa23_players_basic.csv"
#
# - It's a dataset on professional soccer players
# - Rows correspond to players (18,539)
# - Columns contain attributes of players (32)
# - Try to view the dataset before starting

# %%
# Write your own code
data_quiz = pd.read_csv("data_quiz/fifa23_players_basic.csv")

# %% [markdown]
# <font size = "5">
#
# (a) Create a function and apply it to a column <br>
#
# <font size = "3">
#
# Step 1:
# - Define a function with a parameter "country"
# - If "country == United States", status = "US national"
# - Otherwise, status = "Not a US national"
# - The function returns "status"
#
# Step 2:
# - Extract the column "Nationality" in the dataset <br>
# (be carefeful to write the "N" (capitalized)
# - Create a new variable called "is_us_national" <br>
# to assign each player to the correct age bracket
#
# HINT: Use the ".apply()" function

# %%
# Write your own code
def fn_country(country):
    if "country == United States":
        status = "US national"
    else:
        status = "Not a US national"
    return(status)
data_quiz["is_us_national"] = data_quiz["Nationality"].apply(fn_country)

# %% [markdown]
# <font size = "5">
#
# (b) Use queries + global variables
#
# <font size = "3">
#
# - Compute the median of the column "Value(in Euro)" <br>
# and store it as a variable
# - Subset the players whose value is above the mean value <br>
#   using ".query()"
#
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 10) <br>
# Reference the column as ``` `Wage(in Euro)`    ``` inside .query()

# %%
# Write your own code
median_euro = data_quiz["Wage(in Euro)"].median()
players_above_median = data_quiz.query("`Wage(in Euro)` >= @median_euro")

# %% [markdown]
# <font size = "5">
#
# (c) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# - Use ".sort_values()" to order the "Potental" column <br>
# from highest to lowest
# - Get a subset with the 15 players with the highest potential

# %%
# Write your own code
sorted_data = data_quiz.sort_values(by="Potential", ascending = False)
top_potential = sorted_data.iloc[0:15,:]
display(top_potential)
# Out:
#           Known As                         Full Name  Overall  Potential  \
# 4        K. Mbappé                     Kylian Mbappé       91         95
# 21      E. Haaland                    Erling Haaland       88         94
# 82           Pedri              Pedro González López       85         93
# 83        P. Foden                        Phil Foden       85         92
# 63    Vinícius Jr.  Vinícius José de Oliveira Júnior       86         92
# 42      F. de Jong                   Frenkie de Jong       87         92
# 22   G. Donnarumma              Gianluigi Donnarumma       88         92
# 0         L. Messi                      Lionel Messi       91         91
# 16         Ederson         Ederson Santana de Moraes       89         91
# 1       K. Benzema                     Karim Benzema       91         91
# 152    D. Vlahović                    Dušan Vlahović       84         91
# 138     K. Havertz                       Kai Havertz       84         91
# 127       J. Tartt                       Jamie Tartt       84         91
# 124  J. Bellingham                   Jude Bellingham       84         91
# 20      Rúben Dias      Rúben Santos Gato Alves Dias       88         91
#
#      Value(in Euro) Positions Played Best Position  Nationality  \
# 4         190500000            ST,LW            ST       France
# 21        148000000               ST            ST       Norway
# 82        116000000               CM            CM        Spain
# 83        109500000        LW,CF,CAM           CAM      England
# 63        109000000               LW            LW       Brazil
# 42        116500000               CM            CM  Netherlands
# 22        103500000               GK            GK        Italy
# 0          54000000               RW           CAM    Argentina
# 16         88000000               GK            GK       Brazil
# 1          64000000            CF,ST            CF       France
# 152        86500000               ST            ST       Serbia
# 138        84500000        CAM,CF,ST           CAM      Germany
# 127        85500000               ST           CAM      England
# 124        81500000            CM,LM            CM      England
# 20        107500000               CB            CB     Portugal
#
#                                            Image Link  Age  ...  \
# 4    https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# 21   https://cdn.sofifa.net/players/239/085/23_60.png   21  ...
# 82   https://cdn.sofifa.net/players/251/854/23_60.png   19  ...
# 83   https://cdn.sofifa.net/players/237/692/23_60.png   22  ...
# 63   https://cdn.sofifa.net/players/238/794/23_60.png   21  ...
# 42   https://cdn.sofifa.net/players/228/702/23_60.png   25  ...
# 22   https://cdn.sofifa.net/players/230/621/23_60.png   23  ...
# 0    https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 16   https://cdn.sofifa.net/players/210/257/23_60.png   28  ...
# 1    https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 152  https://cdn.sofifa.net/players/246/430/23_60.png   22  ...
# 138  https://cdn.sofifa.net/players/235/790/23_60.png   23  ...
# 127  https://cdn.sofifa.net/players/269/761/23_60.png   24  ...
# 124  https://cdn.sofifa.net/players/252/371/23_60.png   19  ...
# 20   https://cdn.sofifa.net/players/239/818/23_60.png   25  ...
#
#      Weak Foot Rating  Skill Moves  International Reputation  \
# 4                   4            5                         4
# 21                  3            3                         4
# 82                  4            4                         2
# 83                  3            4                         3
# 63                  4            5                         2
# 42                  3            4                         3
# 22                  3            1                         3
# 0                   4            4                         5
# 16                  3            1                         3
# 1                   4            4                         4
# 152                 3            3                         2
# 138                 4            4                         3
# 127                 4            5                         1
# 124                 4            4                         2
# 20                  4            2                         3
#
#      National Team Name                 National Team Image Link  \
# 4                France      https://cdn.sofifa.net/flags/fr.png
# 21               Norway      https://cdn.sofifa.net/flags/no.png
# 82                Spain      https://cdn.sofifa.net/flags/es.png
# 83              England  https://cdn.sofifa.net/flags/gb-eng.png
# 63                    -      https://cdn.sofifa.net/flags/br.png
# 42          Netherlands      https://cdn.sofifa.net/flags/nl.png
# 22                Italy      https://cdn.sofifa.net/flags/it.png
# 0             Argentina      https://cdn.sofifa.net/flags/ar.png
# 16                    -      https://cdn.sofifa.net/flags/br.png
# 1                France      https://cdn.sofifa.net/flags/fr.png
# 152                   -                                        -
# 138             Germany      https://cdn.sofifa.net/flags/de.png
# 127                   -  https://cdn.sofifa.net/flags/gb-eng.png
# 124             England  https://cdn.sofifa.net/flags/gb-eng.png
# 20             Portugal      https://cdn.sofifa.net/flags/pt.png
#
#      National Team Position  National Team Jersey Number Attacking Work Rate  \
# 4                        ST                           10                High
# 21                       ST                            9                High
# 82                       CM                           10                High
# 83                       RW                           20                High
# 63                        -                            -                High
# 42                      CDM                           21                High
# 22                       GK                           21              Medium
# 0                        RW                           10                 Low
# 16                        -                            -              Medium
# 1                        ST                           19              Medium
# 152                       -                            -              Medium
# 138                     SUB                            7              Medium
# 127                       -                            -                High
# 124                     SUB                           26                High
# 20                       CB                            4              Medium
#
#     Defensive Work Rate is_us_national
# 4                   Low    US national
# 21               Medium    US national
# 82                 High    US national
# 83                 High    US national
# 63               Medium    US national
# 42               Medium    US national
# 22               Medium    US national
# 0                   Low    US national
# 16               Medium    US national
# 1                Medium    US national
# 152              Medium    US national
# 138              Medium    US national
# 127                 Low    US national
# 124                High    US national
# 20                 High    US national
#
# [15 rows x 33 columns]

# %% [markdown]
# <font size = "5">
#
# (d) Create a function with five inputs $f(y,x,b0,b1,b2)$
#
# <font size = "3">
#
# $\qquad e = y - b_0 - b_1 * x - b_2 * x^2 $ <br>
# $\qquad e2 = e^2$
#
# - The function should return the mean of e2
# - This is the mean-square error (mse)
# - Call the function "fn_mse"
# - Let $y$ be the column "Potential"
# - Let $x$ be the column "Age"
# - Does <br>
# $\qquad (b_0 = 90, b_1 = -1, b2 = -50)$ or <br>
# $\qquad (b_0 = 90, b_1 = -1, b2 = 0)$ or <br>
# $\qquad (b_0 = 90, b_1 = -1, b3 = 50)$ <br>
# produce the lowest value of mse?

# %%
# Write your own code

def fn_mse(y,x,b0,b1,b2):
    e2 = (y - b0 - b1 * x - b2 * x**2) **2
    return(e2)

y = data_quiz["Potential"]
x = data_quiz["Age"]
fn_mse(y,x,90,-1,-50)
fn_mse(y,x,90,-1,0)
fn_mse(y,x,90, -1, 50)
# Out:
# 0        3747153796
# 1        3336795225
# 2        2961101056
# 3        2305728324
# 4         698122084
#             ...
# 18534     486775969
# 18535     209265156
# 18536     262602025
# 18537     209149444
# 18538     977500225
# Length: 18539, dtype: int64

# %% [markdown]
# <font size = "5">
#
# (e) Split a dataset into subsets
#
# <font size = "3">
#
# - Create ``` list_status = [0,1]```
# - Create ``` list_prob = [0.5, 0.5]```
# - Create a new variable $n$ with the number of rows of the dataset
# - Use
# ```python
#     np.random.choice(list_status,
#                      size = n,
#                      p = list_prob)
# ```
# $\qquad$ to create a new column called "status" <br>
# $\qquad$ which randomly assigns each row to "0" with probability 50% <br>
# $\qquad$ and to 1 with probability 50%
# - Use .query() to subset all observations with status == 0.<br>
# store it in a new dataset called "data0"
# - Use .query() to subset all observations with status == 1.<br>
# store it in a new dataset called "data1"

# %%
# Write your own code
list_status = [0,1]
list_prob = [0.5,0.5]
n = len(data_quiz)
data_quiz["status"] = np.random.choice(list_status, size = n, p = list_prob)

data0 = data_quiz.query("status == 0")
data1 = data_quiz.query("status == 1")

# %% [markdown]
# <font size = "5">
#
# (f) Create two overlapping histogram plots
#
# <font size = "3">
#
# - This function requires the two datasets you created in (e)
# - Display the distribution of "Overall" for "data0" and "data1"
# - Use the "alpha" option to make the graphs semitransparent
# - You will need to add a legend, label the axes, and the title
#
# Note: The goal of this question is to illustrate that random <br>
# assignment produces very similar distributions between two groups

# %%
# Write your own code
plt.hist(x= data0, alpha=0.7)
plt.hist(x= data1, alpha = 0.5)
x= ["data_treated", "data_control"]
plt.legend(labels = x,
           title = "data")
plt.show()
# Out:
# Error in callback <function _draw_all_if_interactive at 0x1159ae660> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/pyplot.py:119, in _draw_all_if_interactive()
#     117 def _draw_all_if_interactive():
#     118     if matplotlib.is_interactive():
# --> 119         draw_all()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/backend_bases.py:2054, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2052 if not self._is_idle_drawing:
#    2053     with self._idle_draw_cntx():
# -> 2054         self.draw(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:405, in FigureCanvasAgg.draw(self)
#     401 # Acquire a lock on the shared font cache.
#     402 with RendererAgg.lock, \
#     403      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     404       else nullcontext()):
# --> 405     self.figure.draw(self.renderer)
#     406     # A GUI class may be need to update a window using this draw, so
#     407     # don't forget to call the superclass.
#     408     super().draw()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/figure.py:3082, in Figure.draw(self, renderer)
#    3079         # ValueError can occur when resizing a window.
#    3081 self.patch.draw(renderer)
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.suppressComposite)
#    3085 for sfig in self.subfigs:
#    3086     sfig.draw(renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/axes/_base.py:3100, in _AxesBase.draw(self, renderer)
#    3097         a.draw(renderer)
#    3098     renderer.stop_rasterizing()
# -> 3100 mimage._draw_list_compositing_images(
#    3101     renderer, self, artists, self.figure.suppressComposite)
#    3103 renderer.close_group('axes')
#    3104 self.stale = False
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/axis.py:1304, in Axis.draw(self, renderer, *args, **kwargs)
#    1301     return
#    1302 renderer.open_group(__name__, gid=self.get_gid())
# -> 1304 ticks_to_draw = self._update_ticks()
#    1305 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1307 for tick in ticks_to_draw:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/axis.py:1192, in Axis._update_ticks(self)
#    1190 major_locs = self.get_majorticklocs()
#    1191 major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1192 major_ticks = self.get_major_ticks(len(major_locs))
#    1193 self.major.formatter.set_locs(major_locs)
#    1194 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/axis.py:1534, in Axis.get_major_ticks(self, numticks)
#    1530     numticks = len(self.get_majorticklocs())
#    1532 while len(self.majorTicks) < numticks:
#    1533     # Update the new tick label properties from the old.
# -> 1534     tick = self._get_tick(major=True)
#    1535     self.majorTicks.append(tick)
#    1536     self._copy_tick_props(self.majorTicks[0], tick)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/axis.py:1483, in Axis._get_tick(self, major)
#    1479     raise NotImplementedError(
#    1480         f"The Axis subclass {self.__class__.__name__} must define "
#    1481         "_tick_class or reimplement _get_tick()")
#    1482 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1483 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/axis.py:422, in XTick.__init__(self, *args, **kwargs)
#     421 def __init__(self, *args, **kwargs):
# --> 422     super().__init__(*args, **kwargs)
#     423     # x in data coords, y in axes coords
#     424     ax = self.axes
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/axis.py:189, in Tick.__init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kwargs)
#     185 for artist in [self.tick1line, self.tick2line, self.gridline,
#     186                self.label1, self.label2]:
#     187     self._set_artist_props(artist)
# --> 189 self.update_position(loc)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/axis.py:465, in XTick.update_position(self, loc)
#     463 self.tick2line.set_xdata((loc,))
#     464 self.gridline.set_xdata((loc,))
# --> 465 self.label1.set_x(loc)
#     466 self.label2.set_x(loc)
#     467 self._loc = loc
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/text.py:1166, in Text.set_x(self, x)
#    1158 """
#    1159 Set the *x* position of the text.
#    1160
#    (...)
#    1163 x : float
#    1164 """
#    1165 self._x = x
# -> 1166 self.stale = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/artist.py:289, in Artist.stale(self, val)
#     283     """
#     284     Whether the artist is 'stale' and needs to be re-drawn for the output
#     285     to match the internal state of the artist.
#     286     """
#     287     return self._stale
# --> 289 @stale.setter
#     290 def stale(self, val):
#     291     self._stale = val
#     293     # if the artist is animated it does not take normal part in the
#     294     # draw stack and is not expected to be drawn as part of the normal
#     295     # draw loop (when not saving) so do not propagate this change
#
# KeyboardInterrupt:
